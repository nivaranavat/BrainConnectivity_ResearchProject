# %%
#1. is data being received even the same x
#2. is the threshold the same x
#3. is the split roi the same x
#4. is the flexibility the same ding very very different
    # 4a is it the threshold x
    #4b is it the graph build
    #is it the flexiblity function,the modularity being calculated is different
    #i think it is supposed to change, because her's changes too each time, there is some randomness

# %%
#testing if it works for complex numbers
import utils 

path = "/Users/niva.ranavat/UCI Research/Data" #constant for our research purposes

drug_list = ("SAL",)
timepoints = [30,60,90,120,150]

small_worldness = utils.phaseScramble_and_smallWorldness(drug_list, path, filesize = 200, iterations = 5, threshold = 0.15)
for drug, sw in small_worldness.items():
    print("Small worldness calculated for:",drug, sw)
    print()
   

drug_list = ("SAL",)
timepoints = [30,60,90,120,150]
result_dict, flexibility,fig = utils.calculate_flexibility(path, drug_list, timepoints)
fig.savefig("testingflex.jpg")
for drug, flex in flexibility.items():
    print("Flexibility calculated for:",drug, flex )
    print()
# Out:
# SAL_11
# SAL_10
# SAL_03
# SAL_04
# SAL_05
# SAL_02
# SAL_12
# SAL_09
# SAL_07
# SAL_01
# SAL_06
# SAL_08
# Small worldness calculated for: SAL [1.055054167342068, 1.0777927323092389, 1.0012846505326651, 1.0555128279961432, 1.0481362212065681, 1.0666984614744002, 1.0170648302803442, 1.0763401545924447, 1.0895752735439277, 1.0872111678631642, 1.1412098603768337, 1.1297726044135326]
#
# SAL_11
# SAL_10
# SAL_03
# SAL_04
# SAL_05
# SAL_02
# SAL_12
# SAL_09
# SAL_07
# SAL_01
# SAL_06
# SAL_08
# Flexibility calculated for: SAL ({30: [0.030514128476025578, 0.032727805609764654, 0.022576836476398958, 0.033432865422384044, 0.03478419616221816, 0.02440688914382054, 0.026048648585086952, 0.030763045046517043, 0.029332588684652994, 0.028198407205214656, 0.03731861434127004, 0.03368659127278144], 60: [0.03353237809039283, 0.030407174039213895, 0.02765755835276758, 0.01992210291724462, 0.030155320080682314, 0.030521407175747695, 0.032808304431197685, 0.028860218511023945, 0.02671694552030826, 0.0272571036041168, 0.032744769175725025, 0.032906049432013], 90: [0.02674291473196837, 0.020339567257080096, 0.034122275384991706, 0.026235582679061658, 0.027692673555174116, 0.03343424957105597, 0.025431988938408277, 0.03414288357302449, 0.023602991501715853, 0.025500315543767114, 0.029375154769127828, 0.029116917767391424], 120: [0.03119891353918061, 0.023557853577449425, 0.028925566837373195, 0.02597499482835385, 0.030634912242714835, 0.030423910454831383, 0.02426998862037085, 0.028448390732314845, 0.021811183050178772, 0.02252265790114316, 0.025391196331146847, 0.029927024946650383], 150: [0.029252966275421764, 0.02802060552240762, 0.027117185616319386, 0.024275708222792864, 0.03020561373818423, 0.025482887869292117, 0.01865484245007087, 0.029922385601288414, 0.028869196647346596, 0.03504002326105951, 0.03042908166639615, 0.025021070300819775]}, {30: [0.5706840821852113, 0.5275205509468645, 0.30616189686629586, 0.4500578037628621, 0.5606663197199638, 0.4635416930415529, 0.35586908382971955, 0.532019720216236, 0.639746370421957, 0.40480135343423385, 0.5988904266557529, 0.5336130298597924], 60: [0.6418306743864253, 0.8904092796343512, 0.9075136334501862, 0.9570421989656731, 0.4477608133192223, 0.6502386746137552, 0.968437901884751, 0.5329713720000654, 1.1758655663129685, 0.5596081326543533, 0.742821152597466, 0.6871007480832261], 90: [0.9450020349998439, 1.0033276465740852, 1.1399942003622232, 0.9838343504648123, 0.6544731531528288, 1.4540931026465171, 1.2217328019431428, 0.7891515542821699, 0.6884205854667125, 0.7842147248815412, 1.2129628514218513, 1.3375584099395434], 120: [1.1240785025145956, 0.553195603176528, 1.2506053897334881, 0.9593779496904561, 0.938194187433142, 1.2022351711989823, 1.4502798078026484, 0.754858021236513, 0.5725435550671928, 1.2172171733338402, 1.3426280074383405, 1.0782531046954917], 150: [1.546829511685971, 1.6089957077319998, 0.927029368743942, 1.6520968096067368, 1.22658155235168, 1.3671476338634823, 0.7216478526737944, 1.3832046174180492, 1.2194746859655028, 1.2205884880037319, 1.2927962442081604, 0.8246855009463022]}, {30: [0.05346938775510204, 0.06204081632653062, 0.07374149659863945, 0.07428571428571429, 0.0620408163265306, 0.052653061224489796, 0.07319727891156462, 0.057823129251700675, 0.04585034013605442, 0.06965986394557823, 0.06231292517006802, 0.06312925170068025], 60: [0.05224489795918367, 0.034149659863945574, 0.030476190476190476, 0.02081632653061224, 0.06734693877551019, 0.04693877551020408, 0.03387755102040816, 0.05414965986394557, 0.022721088435374147, 0.048707482993197285, 0.04408163265306122, 0.04789115646258503], 90: [0.028299319727891153, 0.020272108843537417, 0.02993197278911564, 0.026666666666666665, 0.04231292517006802, 0.022993197278911564, 0.020816326530612245, 0.04326530612244897, 0.03428571428571428, 0.03251700680272108, 0.024217687074829932, 0.0217687074829932], 120: [0.027755102040816326, 0.042585034013605444, 0.02312925170068027, 0.027074829931972792, 0.03265306122448979, 0.025306122448979586, 0.01673469387755102, 0.03768707482993197, 0.03809523809523809, 0.018503401360544215, 0.01891156462585034, 0.027755102040816326], 150: [0.01891156462585034, 0.01741496598639456, 0.0292517006802721, 0.014693877551020407, 0.024625850340136056, 0.018639455782312925, 0.025850340136054417, 0.021632653061224492, 0.0236734693877551, 0.028707482993197277, 0.02353741496598639, 0.030340136054421762]})

# %%
#ok so they are different issue is when calculating flexibility 
#when we are transfering a networkx graph to numpy array

# %%
# small_worldness = utils.phaseScramble_and_smallWorldness(drug_list, path, filesize = 200, iterations = 1, threshold = 0.15)
# for drug, sw in small_worldness.items():
#     print("Small worldness calculated for:",drug, sw)
#     print()

# %%
import matplotlib.pyplot as plt
from pathlib import Path

# %%
#read the MRI data first and plot
roi_timeseries = utils.load_txt(Path('/Users/niva.ranavat/UCI Research/Data/SAL_01'))
fig, ax = plt.subplots(nrows=1 , ncols=3, figsize=(25, 5))
for i in roi_timeseries:
    ax[0].plot(range(200),i)
    ax[0].set_title("SAL Original Time Series")
    ax[0].set_xlabel("Time")
    ax[0].set_ylabel("MRI Value")
    
roi_timeseries = utils.load_txt(Path('/Users/niva.ranavat/UCI Research/Data/SCRSAL_01_1'))
print(roi_timeseries)
for i in roi_timeseries:
    ax[1].plot(range(200),i)
    ax[1].set_title("Phase Scrambled SAL #1 Time Series")
    ax[1].set_xlabel("Time")
    ax[1].set_ylabel("MRI Value")
    
roi_timeseries = utils.load_txt(Path('/Users/niva.ranavat/UCI Research/Data/SCRSAL_01_2/'))
for i in roi_timeseries:
    ax[2].plot(range(200),i)
    ax[2].set_title("Phase Scrambled SAL #2  Time Series")
    ax[2].set_xlabel("Time")
    ax[2].set_ylabel("MRI Value")
